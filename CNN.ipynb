# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\kskfb\miniconda3\lib\site-packages (1.26.4)

# %%
import numpy as np

# %%
class ConvLayer:
    #Инициализируем наш слой, задавая ему фильтры
    def __init__(self, num_filters, filter_size):
        self.num_filters = num_filters
        self.filter_size = filter_size
        self.filters = np.random.randn(num_filters, filter_size, filter_size) / filter_size**2


#Пробегаемся по картинке всей по регионам, которые равны размеру фильтра
    def iterate_regions(self, image):
        h, w = image.shape
        for i in range(h - self.filter_size + 1):
            for j in range(w - self.filter_size + 1):
                img_region = image[i:(i + self.filter_size), j:(j + self.filter_size)]
                yield img_region, i, j


# Основной метод, благодаря которому, мы пробегаемся по картинке, применяем фильтры на каждый регион и получаем уже новое изображение, которое прошло через сверточный слой 
    def forward(self, input):
        self.last_input = input
        h, w = input.shape
        output = np.zeros((h - self.filter_size + 1, w - self.filter_size + 1, self.num_filters))
        print(f"Input shape: {input.shape}")
        for img_region, i, j in self.iterate_regions(input):
            print(f"Region shape: {img_region.shape}, Position: ({i}, {j})")
            output[i, j] = np.sum(img_region * self.filters, axis=(1, 2))
        print(f"Output shape: {output.shape}")
        return output

# %%
input_image = np.random.randn(10, 10)  # случайное изображение 10x10
conv_layer = ConvLayer(3, 3)  # слой свертки с 3 фильтрами размера 3x3
print("Наше изображение")
print(input_image)
output = conv_layer.forward(input_image)


print(output)
# Out:
# Наше изображение
# [[-0.17359716 -0.76717573 -1.53479492  0.23610847 -1.47543528  0.13805603
#    0.35062439  1.04901297  0.72828025 -0.11224901]
#  [ 0.93919703 -1.3173597   1.52589555  1.61069679 -0.97973946 -0.05191477
#    0.08072203  2.34586812 -0.66851027  0.78286144]
#  [ 0.97596075 -0.47685051 -1.14087122  1.85714769 -0.63317529 -0.823637
#   -1.84966723  0.36714671  0.45491701  0.85625955]
#  [ 0.63212447 -0.90042729 -1.58466562 -0.9071824  -0.00418618 -0.56846968
#   -0.40791425  1.14564212 -1.94896966 -0.40717787]
#  [ 1.36907659 -0.79018531  1.77273298 -0.75150963  2.82886136  1.0446948
#   -0.69857453  1.7558589   0.25313014  1.10605497]
#  [-1.66278573  0.36102856  0.1287962  -0.31094854 -1.9848446  -0.65377666
#   -1.78091503  2.05603799  0.75620649  0.97865082]
#  [ 0.01449576  0.92636078  1.13970407  2.14845909  0.94263958  0.93177115
#   -0.69554899 -0.18069717  0.93307615 -2.18666241]
#  [ 0.33251805 -0.17457832 -0.22031121  0.45311153 -1.40920615 -0.36282181
#   -0.35349827 -0.77288012  0.42001187 -0.46608958]
#  [-0.99251923  0.35040632 -0.83884978  0.13368727 -0.24182535  0.09818972
#   -1.22214569  0.7133036  -0.13053255  0.13293761]
#  [ 0.66945484 -0.52036792 -0.95599891  1.25238468  0.85967758  0.03798657
#   -1.11126179  0.36367652  0.82709575 -0.27701538]]
# Input shape: (10, 10)
# Region shape: (3, 3), Position: (0, 0)
# Region shape: (3, 3), Position: (0, 1)
# Region shape: (3, 3), Position: (0, 2)
# Region shape: (3, 3), Position: (0, 3)
# Region shape: (3, 3), Position: (0, 4)
# Region shape: (3, 3), Position: (0, 5)
# Region shape: (3, 3), Position: (0, 6)
# Region shape: (3, 3), Position: (0, 7)
# Region shape: (3, 3), Position: (1, 0)
# Region shape: (3, 3), Position: (1, 1)
# Region shape: (3, 3), Position: (1, 2)
# Region shape: (3, 3), Position: (1, 3)
# Region shape: (3, 3), Position: (1, 4)
# Region shape: (3, 3), Position: (1, 5)
# Region shape: (3, 3), Position: (1, 6)
# Region shape: (3, 3), Position: (1, 7)
# Region shape: (3, 3), Position: (2, 0)
# Region shape: (3, 3), Position: (2, 1)
# Region shape: (3, 3), Position: (2, 2)
# Region shape: (3, 3), Position: (2, 3)
# Region shape: (3, 3), Position: (2, 4)
# Region shape: (3, 3), Position: (2, 5)
# Region shape: (3, 3), Position: (2, 6)
# Region shape: (3, 3), Position: (2, 7)
# Region shape: (3, 3), Position: (3, 0)
# Region shape: (3, 3), Position: (3, 1)
# Region shape: (3, 3), Position: (3, 2)
# Region shape: (3, 3), Position: (3, 3)
# Region shape: (3, 3), Position: (3, 4)
# Region shape: (3, 3), Position: (3, 5)
# Region shape: (3, 3), Position: (3, 6)
# Region shape: (3, 3), Position: (3, 7)
# Region shape: (3, 3), Position: (4, 0)
# Region shape: (3, 3), Position: (4, 1)
# Region shape: (3, 3), Position: (4, 2)
# Region shape: (3, 3), Position: (4, 3)
# Region shape: (3, 3), Position: (4, 4)
# Region shape: (3, 3), Position: (4, 5)
# Region shape: (3, 3), Position: (4, 6)
# Region shape: (3, 3), Position: (4, 7)
# Region shape: (3, 3), Position: (5, 0)
# Region shape: (3, 3), Position: (5, 1)
# Region shape: (3, 3), Position: (5, 2)
# Region shape: (3, 3), Position: (5, 3)
# Region shape: (3, 3), Position: (5, 4)
# Region shape: (3, 3), Position: (5, 5)
# Region shape: (3, 3), Position: (5, 6)
# Region shape: (3, 3), Position: (5, 7)
# Region shape: (3, 3), Position: (6, 0)
# Region shape: (3, 3), Position: (6, 1)
# Region shape: (3, 3), Position: (6, 2)
# Region shape: (3, 3), Position: (6, 3)
# Region shape: (3, 3), Position: (6, 4)
# Region shape: (3, 3), Position: (6, 5)
# Region shape: (3, 3), Position: (6, 6)
# Region shape: (3, 3), Position: (6, 7)
# Region shape: (3, 3), Position: (7, 0)
# Region shape: (3, 3), Position: (7, 1)
# Region shape: (3, 3), Position: (7, 2)
# Region shape: (3, 3), Position: (7, 3)
# Region shape: (3, 3), Position: (7, 4)
# Region shape: (3, 3), Position: (7, 5)
# Region shape: (3, 3), Position: (7, 6)
# Region shape: (3, 3), Position: (7, 7)
# Output shape: (8, 8, 3)
# [[[ 0.21008481 -0.17841606 -0.83505435]
#   [-0.11207968  0.47084263  0.25826472]
#   [ 0.81150336 -0.13246162  0.3227215 ]
#   [-0.19419145 -0.48279122 -0.54364991]
#   [-0.44601696 -0.18409832 -0.10975039]
